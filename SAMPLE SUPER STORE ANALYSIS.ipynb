# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\DHIRAJ CHAUDHARY\Desktop\DIGIPERFORM\EXCEL\SUPER SAMPLE DATA.xlsx')
print(df)
# Out:
#      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
#          Unnamed: 4 customer ID      customer name     segement  \
# ...

# %%
df.iloc[:10,3:6]
# Out:
#             Unnamed: 3      Unnamed: 4 customer ID
# 0  2016-11-11 00:00:00    Second Class    CG-12520
# 1  2016-11-11 00:00:00    Second Class    CG-12520
# 2            6/16/2016    Second Class    DV-13045
# 3           10/18/2015  Standard Class    SO-20335
# 4           10/18/2015  Standard Class    SO-20335
# 5            6/14/2014  Standard Class    BH-11710
# 6            6/14/2014  Standard Class    BH-11710
# 7            6/14/2014  Standard Class    BH-11710
# 8            6/14/2014  Standard Class    BH-11710
# 9            6/14/2014  Standard Class    BH-11710

# %%
df.rename(columns={'product ID': 'product_ID', 'product name': 'product_name'}, inplace=True)

# %%
print(df)
# Out:
#      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
#          Unnamed: 4 customer ID      customer name     segement  \
# ...

# %%
print(df["sales"].sum())
# Out:
# 31356.231699999997

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
# ...

# %%
print(df.items)
# Out:
# <bound method DataFrame.items of      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
# ...

# %%
df.isna()
# Out:
#      Unnamed: 0  ORDER ID  Unnamed: 2  Unnamed: 3  Unnamed: 4  customer ID  \
# 0         False     False       False       False       False        False
# 1         False     False       False       False       False        False
# 2         False     False       False       False       False        False
# 3         False     False       False       False       False        False
# 4         False     False       False       False       False        False
# ..          ...       ...         ...         ...         ...          ...
# 149       False     False       False       False       False        False
# 150       False     False       False       False       False        False
# 151       False     False       False       False       False        False
# 152       False     False       False       False       False        False
# 153       False     False       False       False       False        False
#
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# ORDER ID         0
# Unnamed: 2       0
# Unnamed: 3       0
# Unnamed: 4       0
# customer ID      0
# customer name    0
# segement         0
# country          0
# city             0
# state            0
# postal code      0
# Rgion            0
# product ID       0
# category         0
# sub-category     0
# product name     0
# sales            0
# Unnamed: 18      0
# Unnamed: 19      0
# #name            0
# dtype: int64

# %%
df1 = df.copy()
print(df1)
# Out:
#      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
#          Unnamed: 4 customer ID      customer name     segement  \
# ...

# %%
print(df1)
# Out:
#      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
#          Unnamed: 4 customer ID      customer name     segement  \
# ...

# %%
df1.drop(['country','city'],axis =1,inplace=True)

# %%
print(df1)
# Out:
#      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
#          Unnamed: 4 customer ID      customer name     segement       state  \
# ...

# %%
print(df)
# Out:
#      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
#          Unnamed: 4 customer ID      customer name     segement       state  \
# ...

# %%
print(df)
# Out:
#      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
#          Unnamed: 4 customer ID      customer name     segement  \
# ...

# %%
print(df1)
# Out:
#      Unnamed: 0        ORDER ID           Unnamed: 2           Unnamed: 3  \
# 0             1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1             2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2             3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3             4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4             5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ..          ...             ...                  ...                  ...
# 149         150  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 150         151  CA-2016-114489  2016-05-12 00:00:00  2016-09-12 00:00:00
# 151         152  CA-2016-158834            3/13/2016            3/16/2016
# 152         153  CA-2016-158834            3/13/2016            3/16/2016
# 153         154  CA-2015-124919            5/31/2015  2015-02-06 00:00:00
#
#          Unnamed: 4 customer ID      customer name     segement       state  \
# ...
